# %%
from BurstCube.simGenerator import configurator
conf = configurator('config.yaml')

from BurstCube.bcSim import simFiles
sfs = simFiles('config.yaml')

# print(sfs.sims[0].simFile)
# type(sfs.sims[0].simFile)# fileN = 'FIN_1000.000keV_15.00ze_0.00az.inc1.id1.sim'

area = sfs.calculateAeff()
# Out:
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_4.04az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_8.09az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_12.13az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_16.18az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_20.22az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_24.27az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_28.31az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_32.36az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_36.40az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_40.45az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_44.49az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_48.54az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_52.58az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_56.63az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_60.67az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_64.72az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_68.76az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_72.81az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_76.85az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_80.90az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_84.94az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_88.99az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_93.03az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_97.08az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_101.12az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_105.17az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_109.21az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_113.26az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_117.30az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_121.35az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_125.39az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_129.44az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_133.48az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_137.53az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_141.57az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_145.62az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_149.66az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_153.71az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_157.75az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_161.80az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_165.84az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_169.89az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_173.93az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_177.98az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_182.02az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_186.07az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_190.11az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_194.16az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_198.20az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_202.25az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_206.29az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_210.34az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_214.38az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_218.43az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_222.47az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_226.52az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_230.56az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_234.61az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_238.65az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_242.70az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_246.74az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_250.79az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_254.83az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_258.88az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_262.92az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_266.97az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_271.01az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_275.06az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_279.10az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_283.15az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_287.19az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_291.24az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_295.28az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_299.33az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_303.37az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_307.42az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_311.46az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_315.51az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_319.55az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_323.60az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_327.64az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_331.69az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_335.73az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_339.78az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_343.82az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_347.87az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_351.91az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_355.96az.inc1.id1.sim
# Loading /home/laura/Research/local_test/200_15_c//HF200_200.000keV_15.00ze_360.00az.inc1.id1.sim

# %%
simulation = 0; detectOne = 0; detectTwo = 0; detectThree = 0; detectFour = 0
percentOne = 0; percentTwo = 0; percentThree = 0; percentFour = 0
# detectOneTot = 0
# detectTwoTot = 0
# detectThreeTot = 0
# detectFourTot = 0
    
detectTot = 0
triggerDict = {}
f = open("dict.txt","w")
doubTriggerDict = {}
triggerSim = []
triggerSimNum = []
triggerSimCount = []
triggerSimEnergy = []
Det1 = []
Det2 = []
Det3 = []
Det4 = []
spercentOne = 0
spercentTwo = 0
spercentThree = 0
spercentFour = 0
simType = ''
# count = 0

import numpy as np
# triggerData = np.zeros(len(self.sims)), dtype={'names': ['keV', 'ze', 'az', 'counterXX', 'counterNXX', 'counterNXY', 'counterXY'], 'formats': ['float32', 'float32', 'float32','float32', 'float32', 'float32', 'float32']}

for file in sfs.sims:
    simulation = simulation + 1
#     count += 1
#     print(file.simFile)
    import re
    counterXX = 0
    counterNXX = 0
    counterNXY = 0
    counterXY = 0
    count = 0 
    d = 0
    prevLine = 'random'
    counter = 0

    with open(file.simFile) as sim:

#         print(file.simFile)
#         triggerDict = {'trig': [0], 'd' : 'sample'}

        for i, line in enumerate(sim):

            if line.startswith('ID'):
                ID = line.split()

                for i in range(len(ID)):
                    trigger = ID[1]

            if line.startswith('HTsim'):
                data = line.split(";")
                data = [w.strip(' ') for w in data]
#                 counter = counter + 1
        
                data[1] = float(data[1])
                data[2] = float(data[2])
#                 print(data[1])
#                 print("HELLO")
#                 print(data[2])
#                 print("GOODBYE")
#                 for i in range(len(data)):
#                 triggerDict.setdefault('triggers', [])
#                 triggerDict.setdefault('d', [])

                
                if (abs(5.52500 - data[1]) <= 0.05) and  (abs(5.52500 - data[2]) <= .05):
                    counterXX += 1
                    
                    d = 1
#                     triggerDict['trig'].append(counterXX)
#                     triggerDict['d'].append(d)
                    
                elif (abs(-5.52500 - data[1]) <= 0.05) and  (abs(5.52500 - data[2]) <= .05):
                    counterNXX += 1
                    d = 2
#                     triggerDict['trig'].append(counterNXX)
#                     triggerDict['d'].append(d)
                    
                elif (abs(-5.52500 - data[1]) <= 0.05) and  (abs(-5.52500 - data[2]) <= .05):
                    counterNXY += 1
                    d = 3
#                     triggerDict['trig'].append(counterNXY)
#                     triggerDict['d'].append(d)
                    
                elif (abs(5.52500 - data[1]) <= 0.05) and  (abs(-5.52500 - data[2]) <= .05):
                    counterXY += 1
                    d = 4
#                     triggerDict['trig'].append(counterXY)
#                     triggerDict['d'].append(d)
                    
#                 detectOne = counterXX + detectOne
#                 detectTwo = counterNXX + detectTwo
#                 detectThree = counterNXY + detectThree
#                 detectFour = counterXY + detectFour
#                 print(detectOne)
#                 print(detectTwo)
#                 print(detectThree)
#                 print(detectFour)
#                 print('*****')
                counter += 1   
                
            if prevLine.startswith('HTsim') and line.startswith('HTsim'):
                sfo = re.split('[_ . //]', file.simFile)
#                 doubTriggerDict['energy'] = sfo[4]
#                 doubTriggerDict['zenith'] = sfo[6]
#                 doubTriggerDict['azimuth'] = sfo[8]
#                 doubTriggerDict['trigNum'] = trigger
    
            prevLine = line
            if counterXX > (counterNXX and counterNXY and counterXY):
                triggerSimMax = counterXX
                triggerSimType = 'counterXX'
            elif counterNXX > (counterXX and counterNXY and counterXY):
                triggerSimMax = counterNXX
                triggerSimType = 'counterNXX'
            elif counterNXY > (counterXX and counterNXX and counterXY):
                triggerSimMax = counterNXY
                triggerSimType = 'counterNXY'

            elif counterXY > (counterXX and counterNXX and counterNXY):
                triggerSimMax = counterXY
                triggerSimType = 'counterXY'
            count += 1

            sfo = re.split('[/ _]', file.simFile)
    
    triggerSimCount.append(triggerSimType)
    triggerSimNum.append(triggerSimMax)
    triggerSim.append(triggerSimMax)
    triggerSim.append(triggerSimType)
#     triggerSimEnergy.append(sfo[12])
    
    spercentOne = counterXX / counter * 100
    spercentTwo = counterNXX / counter * 100        
    spercentThree = counterNXY / counter * 100
    spercentFour = counterXY / counter * 100
    
#     print(counter, spercentOne)
    Det1.append([spercentOne])
    Det2.append([spercentTwo])
    Det3.append([spercentThree])
    Det4.append([spercentFour])
    
    
#             print('***', trigger)

#             vars = re.split('[_ .]', file.simFile)
#             print("----------------------------------------------------------------------------")
#             print('Simulation', simulation, '--', trigger, ': Energy ({} keV), Azimuth ({} degrees), Zenith ({} degrees)'.format(vars[3], vars[5], vars[7]))
#             print("----------------------------------------------------------------------------")

#             print('Detector 1 has', counterXX , 'hits.')
#             print('Detector 2 has', counterNXX , 'hits.')
#             print('Detector 3 has', counterNXY , 'hits.')
#             print('Detector 4 has', counterXY , 'hits.')
        
#     print('**', count)
    detectOne = counterXX + detectOne
    detectTwo = counterNXX + detectTwo
    detectThree = counterNXY + detectThree
    detectFour = counterXY + detectFour

detectTot = detectOne + detectTwo + detectThree + detectFour
# print(detectOne, detectTot)
percentOne = detectOne / detectTot * 100
percentTwo = detectTwo / detectTot * 100
percentThree = detectThree / detectTot * 100
percentFour = detectFour / detectTot * 100

'''Important, but not printed for saving purposes'''
# print('**', percentOne, "**", percentTwo, '**', percentThree, "**", percentFour, "**")

import operator
'''Important, but not printed for saving purposes'''
print(sorted(enumerate(triggerSimNum), key=operator.itemgetter(1)))

Energy = list(area['keV'])
'''Important, but not printed for saving purposes'''
# c = 0
# for i in range(len(triggerSimCount)):
#     print((i+1), 'Index:', c, 'Value: ', triggerSimCount[i], 'Energy:', Energy[i])
#     c = c + 1

Azimuth = list(area['az'])
Azimuth1 = []
for element in Azimuth:
    Azimuth1.append([element])
Azimuth = Azimuth1

triggerDict['Azimuth'] = Azimuth
triggerDict['Detector1'] = Det1
triggerDict['Detector2'] = Det2
triggerDict['Detector3'] = Det3
triggerDict['Detector4'] = Det4
# Out:
# [(41, 224), (44, 226), (42, 228), (38, 229), (40, 236), (28, 244), (35, 245), (37, 246), (32, 248), (61, 250), (36, 251), (39, 255), (49, 258), (54, 258), (29, 260), (31, 260), (53, 262), (24, 266), (33, 267), (48, 267), (34, 270), (57, 270), (63, 270), (69, 271), (26, 272), (22, 273), (45, 274), (65, 274), (10, 276), (11, 276), (12, 277), (5, 278), (13, 278), (14, 278), (52, 278), (55, 278), (62, 278), (25, 279), (66, 279), (18, 280), (30, 280), (43, 280), (23, 281), (46, 281), (0, 282), (9, 282), (27, 282), (51, 283), (47, 284), (73, 284), (82, 284), (67, 285), (50, 286), (71, 286), (83, 286), (56, 287), (59, 287), (89, 287), (8, 288), (21, 288), (84, 288), (3, 289), (70, 290), (80, 290), (76, 293), (20, 294), (85, 295), (4, 296), (17, 296), (72, 296), (79, 296), (87, 297), (2, 298), (75, 298), (81, 298), (68, 299), (7, 300), (1, 302), (58, 303), (77, 305), (6, 309), (16, 309), (78, 310), (86, 310), (88, 311), (15, 313), (60, 316), (64, 317), (19, 320), (74, 325)]

# %%
from astropy.table import Table, Column
from astropy.io import fits

# hdulist = Table([Energy, Azimuth, Det1, Det2, Det3, Det4], names=('Energy', 'Azimuth', 'Det1', 'Det2', 'Det3', 'Det4'))
# hdulist.write('localizeTable.fits', format='fits')

# t1 = fits.open('/home/laura/Research/local_test/100_0_c/localizeTable.fits')
# t2 = fits.open('localizeTable.fits')

# hdu = fits.BinTableHDU.from_columns([fits.Column(name='Energy', format='L', array=(Energy)),fits.Column(name='Azimuth', format='D', array=(Azimuth)), fits.Column(name='Det1', format='L', array=(Det1)), fits.Column(name='Det2', format='L', array=(Det2)), fits.Column(name='Det3', format='L', array=(Det3)), fits.Column(name='Det4', format='L', array=(Det4))]) 
# hdu.writeto('localizeTrial.fits')

hdr = fits.Header()
hdr['HEADER'] = 'SIM 200 keV, 15 ze'
primary_hdu = fits.PrimaryHDU(header=hdr)
                                        
hdul = fits.HDUList([primary_hdu, hdu])
hdul.writeto('localizeTrial2.fits')
                                        

# print(t2)

# t = t1[1].columns + t2[1].columns
# hdu = pyfits.new_table(t)
# hdu.writeto('localizeTable.fits')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-25-425629cce53c> in <module>()
#      16
#      17 hdul = fits.HDUList([primary_hdu, hdu])
# ---> 18 hdul.writeto('localizeTrial2.fits')
#      19
#      20
#
# ~/anaconda3/lib/python3.6/site-packages/astropy/utils/decorators.py in wrapper(*args, **kwargs)
#     486                         # one with the name of the new argument to the function
#     487                         kwargs[new_name[i]] = value
# --> 488             return function(*args, **kwargs)
#     489
#     490         return wrapper
#
# ~/anaconda3/lib/python3.6/site-packages/astropy/io/fits/hdu/hdulist.py in writeto(self, fileobj, output_verify, overwrite, checksum)
#     865         # file object that's open to write only, or in append/update modes
#     866         # but only if the file doesn't exist.
# --> 867         fileobj = _File(fileobj, mode='ostream', overwrite=overwrite)
#     868         hdulist = self.fromfile(fileobj)
#     869         try:
#
# ~/anaconda3/lib/python3.6/site-packages/astropy/utils/decorators.py in wrapper(*args, **kwargs)
#     486                         # one with the name of the new argument to the function
#     487                         kwargs[new_name[i]] = value
# --> 488             return function(*args, **kwargs)
#     489
#     490         return wrapper
#
# ~/anaconda3/lib/python3.6/site-packages/astropy/io/fits/file.py in __init__(self, fileobj, mode, memmap, overwrite, cache)
#     173             self._open_fileobj(fileobj, mode, overwrite)
#     174         elif isinstance(fileobj, str):
# --> 175             self._open_filename(fileobj, mode, overwrite)
#     176         else:
#     177             self._open_filelike(fileobj, mode, overwrite)
#
# ~/anaconda3/lib/python3.6/site-packages/astropy/io/fits/file.py in _open_filename(self, filename, mode, overwrite)
#     515
#     516         if mode == 'ostream':
# --> 517             self._overwrite_existing(overwrite, None, True)
#     518
#     519         if os.path.exists(self.name):
#
# ~/anaconda3/lib/python3.6/site-packages/astropy/io/fits/file.py in _overwrite_existing(self, overwrite, fileobj, closed)
#     412                     os.remove(self.name)
#     413             else:
# --> 414                 raise OSError("File {!r} already exists.".format(self.name))
#     415
#     416     def _try_read_compressed(self, obj_or_name, magic, mode, ext=''):
#
# OSError: File 'localizeTrial2.fits' already exists.

# %%
f = fits.open('localizeTrial.fits')
f['Energy']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-1c9bca7e15b7> in <module>()
#       1 f = fits.open('localizeTrial.fits')
# ----> 2 f['Energy']
#
# ~/anaconda3/lib/python3.6/site-packages/astropy/io/fits/hdu/hdulist.py in __getitem__(self, key)
#     311         try:
#     312             return self._try_while_unread_hdus(super().__getitem__,
# --> 313                                                self._positive_index_of(key))
#     314         except IndexError as e:
#     315             # Raise a more helpful IndexError if the file was not fully read.
#
# ~/anaconda3/lib/python3.6/site-packages/astropy/io/fits/hdu/hdulist.py in _positive_index_of(self, key)
#     700         """
#     701
# --> 702         index = self.index_of(key)
#     703
#     704         if index >= 0:
#
# ~/anaconda3/lib/python3.6/site-packages/astropy/io/fits/hdu/hdulist.py in index_of(self, key)
#     681
#     682         if (found is None):
# --> 683             raise KeyError('Extension {!r} not found.'.format(key))
#     684         else:
#     685             return found
#
# KeyError: "Extension 'Energy' not found."
