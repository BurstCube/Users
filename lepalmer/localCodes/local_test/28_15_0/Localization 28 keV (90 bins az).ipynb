# %%
from BurstCube.simGenerator import configurator
conf = configurator('config.yaml')

from BurstCube.bcSim import simFiles
sfs = simFiles('config.yaml')

print(sfs.sims[0].simFile)
type(sfs.sims[0].simFile)# fileN = 'FIN_1000.000keV_15.00ze_0.00az.inc1.id1.sim'
# Out:
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_360.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_355.96az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_351.91az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_347.87az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_343.82az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_339.78az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_335.73az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_331.69az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_327.64az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_323.60az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_319.55az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_315.51az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_311.46az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_307.42az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_303.37az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_299.33az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_295.28az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_291.24az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_287.19az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_283.15az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_279.10az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_275.06az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_271.01az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_266.97az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_262.92az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_258.88az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_254.83az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_250.79az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_246.74az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_242.70az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_238.65az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_234.61az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_230.56az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_226.52az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_222.47az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_218.43az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_214.38az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_210.34az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_206.29az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_202.25az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_198.20az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_194.16az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_190.11az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_186.07az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_182.02az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_177.98az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_173.93az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_169.89az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_165.84az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_161.80az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_157.75az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_153.71az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_149.66az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_145.62az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_141.57az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_137.53az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_133.48az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_129.44az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_125.39az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_121.35az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_117.30az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_113.26az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_109.21az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_105.17az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_101.12az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_97.08az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_93.03az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_88.99az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_84.94az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_80.90az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_76.85az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_72.81az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_68.76az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_64.72az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_60.67az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_56.63az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_52.58az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_48.54az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_44.49az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_40.45az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_36.40az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_32.36az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_28.31az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_24.27az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_20.22az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_16.18az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_12.13az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_8.09az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_4.04az.inc1.id1.sim
# Loading /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_0.00az.inc1.id1.sim
# /home/laura/Research/local_test/28_15_0//FIN_28.000keV_15.00ze_360.00az.inc1.id1.sim
# str

# %%
simulation = 0; detectOne = 0; detectTwo = 0; detectThree = 0; detectFour = 0
percentOne = 0; percentTwo = 0; percentThree = 0; percentFour = 0
# detectOneTot = 0
# detectTwoTot = 0
# detectThreeTot = 0
# detectFourTot = 0
    
detectTot = 0

doubTriggerDict = {}
triggerSim = []
triggerSimNum = []
triggerSimCount = []
triggerSimAz = []

simType = ''
count = -1

import numpy as np
# triggerData = np.zeros(len(self.sims)), dtype={'names': ['keV', 'ze', 'az', 'counterXX', 'counterNXX', 'counterNXY', 'counterXY'], 'formats': ['float32', 'float32', 'float32','float32', 'float32', 'float32', 'float32']}

for file in sfs.sims:
    simulation = simulation + 1
    count += 1
#     print(file.simFile)
    import re
    counterXX = 0
    counterNXX = 0
    counterNXY = 0
    counterXY = 0
    d = 0
    prevLine = 'random'
    counter = 0

    with open(file.simFile) as sim:

#         print(file.simFile)
#         triggerDict = {'trig': [0], 'd' : 'sample'}

        for i, line in enumerate(sim):

            if line.startswith('ID'):
                ID = line.split()

                for i in range(len(ID)):
                    trigger = ID[1]

            if line.startswith('HTsim'):
                data = line.split(";")
                data = [w.strip(' ') for w in data]
#                 counter = counter + 1
        
                data[1] = float(data[1])
                data[2] = float(data[2])
#                 print(data[1])
#                 print("HELLO")
#                 print(data[2])
#                 print("GOODBYE")
#                 for i in range(len(data)):
#                 triggerDict.setdefault('triggers', [])
#                 triggerDict.setdefault('d', [])

                
                if (abs(5.52500 - data[1]) <= 0.05) and  (abs(5.52500 - data[2]) <= .05):
                    counterXX += 1
                    
                    d = 1
#                     triggerDict['trig'].append(counterXX)
#                     triggerDict['d'].append(d)
                    
                elif (abs(-5.52500 - data[1]) <= 0.05) and  (abs(5.52500 - data[2]) <= .05):
                    counterNXX += 1
                    d = 2
#                     triggerDict['trig'].append(counterNXX)
#                     triggerDict['d'].append(d)
                    
                elif (abs(-5.52500 - data[1]) <= 0.05) and  (abs(-5.52500 - data[2]) <= .05):
                    counterNXY += 1
                    d = 3
#                     triggerDict['trig'].append(counterNXY)
#                     triggerDict['d'].append(d)
                    
                elif (abs(5.52500 - data[1]) <= 0.05) and  (abs(-5.52500 - data[2]) <= .05):
                    counterXY += 1
                    d = 4
#                     triggerDict['trig'].append(counterXY)
#                     triggerDict['d'].append(d)
                    
#                 detectOne = counterXX + detectOne
#                 detectTwo = counterNXX + detectTwo
#                 detectThree = counterNXY + detectThree
#                 detectFour = counterXY + detectFour
#                 print(detectOne)
#                 print(detectTwo)
#                 print(detectThree)
#                 print(detectFour)
#                 print('*****')
                counter += 1   
                
            if prevLine.startswith('HTsim') and line.startswith('HTsim'):
                sfo = re.split('[_ . //]', file.simFile)
#                 doubTriggerDict['energy'] = sfo[4]
#                 doubTriggerDict['zenith'] = sfo[6]
#                 doubTriggerDict['azimuth'] = sfo[8]
#                 doubTriggerDict['trigNum'] = trigger
    
            prevLine = line
            if counterXX > (counterNXX and counterNXY and counterXY):
                triggerSimMax = counterXX
                triggerSimType = 'counterXX'
            elif counterNXX > (counterXX and counterNXY and counterXY):
                triggerSimMax = counterNXX
                triggerSimType = 'counterNXX'
            elif counterNXY > (counterXX and counterNXX and counterXY):
                triggerSimMax = counterNXY
                triggerSimType = 'counterNXY'

            elif counterXY > (counterXX and counterNXX and counterNXY):
                triggerSimMax = counterXY
                triggerSimType = 'counterXY'
            sfo = re.split('[// .]', file.simFile)
    triggerSimCount.append(triggerSimType)
    triggerSimNum.append(triggerSimMax)
    triggerSim.append(triggerSimMax)
    triggerSim.append(triggerSimType)
    triggerSimAz.append(sfo[10])
    

    
#             print('***', trigger)

#             vars = re.split('[_ .]', file.simFile)
#             print("----------------------------------------------------------------------------")
#             print('Simulation', simulation, '--', trigger, ': Energy ({} keV), Azimuth ({} degrees), Zenith ({} degrees)'.format(vars[3], vars[5], vars[7]))
#             print("----------------------------------------------------------------------------")

#             print('Detector 1 has', counterXX , 'hits.')
#             print('Detector 2 has', counterNXX , 'hits.')
#             print('Detector 3 has', counterNXY , 'hits.')
#             print('Detector 4 has', counterXY , 'hits.')
        
#     print('**', count)
    detectOne = counterXX + detectOne
    detectTwo = counterNXX + detectTwo
    detectThree = counterNXY + detectThree
    detectFour = counterXY + detectFour

detectTot = detectOne + detectTwo + detectThree + detectFour
# print(detectOne, detectTot)
percentOne = detectOne / detectTot * 100
percentTwo = detectTwo / detectTot * 100
percentThree = detectThree / detectTot * 100
percentFour = detectFour / detectTot * 100

print('**', percentOne, "**", percentTwo, '**', percentThree, "**", percentFour, "**")
# print(triggerDict)


'''Next section of code: printing out all the important data!'''

import operator
print(sorted(enumerate(triggerSimNum), key=operator.itemgetter(1)))

c = 0
for i in range(len(triggerSimCount)):
    print('Index:', c, 'Value: ' ,triggerSimCount[i], 'Az:', triggerSimAz[i])
    c = c + 1
# Out:
# ** 25.11777777777778 ** 25.00111111111111 ** 24.653333333333332 ** 25.227777777777778 **
# [(44, 199), (47, 206), (45, 207), (49, 209), (48, 217), (52, 221), (50, 223), (51, 228), (54, 234), (53, 240), (57, 243), (32, 244), (55, 249), (56, 249), (40, 257), (58, 260), (37, 262), (60, 262), (61, 262), (33, 266), (59, 267), (39, 274), (35, 275), (63, 276), (26, 282), (41, 283), (65, 284), (36, 285), (38, 288), (62, 290), (8, 291), (69, 293), (28, 296), (75, 297), (4, 299), (46, 303), (9, 305), (85, 305), (24, 307), (66, 308), (87, 308), (64, 309), (25, 310), (30, 310), (3, 311), (16, 311), (22, 311), (70, 311), (0, 313), (20, 313), (84, 313), (29, 314), (68, 314), (18, 316), (86, 317), (27, 318), (82, 318), (5, 320), (6, 321), (42, 322), (43, 323), (21, 326), (81, 326), (17, 327), (7, 328), (73, 329), (78, 329), (89, 329), (1, 330), (10, 330), (79, 330), (80, 330), (15, 332), (23, 332), (67, 332), (2, 333), (74, 334), (12, 340), (19, 340), (34, 341), (71, 341), (88, 344), (76, 346), (14, 347), (72, 351), (77, 355), (83, 357), (11, 359), (13, 360), (31, 360)]
# Index: 0 Value:  counterXX Az: 00az
# Index: 1 Value:  counterXX Az: 96az
# Index: 2 Value:  counterXY Az: 91az
# Index: 3 Value:  counterXY Az: 87az
# Index: 4 Value:  counterXY Az: 82az
# Index: 5 Value:  counterXY Az: 78az
# Index: 6 Value:  counterXY Az: 73az
# Index: 7 Value:  counterXY Az: 69az
# Index: 8 Value:  counterXY Az: 64az
# Index: 9 Value:  counterXY Az: 60az
# Index: 10 Value:  counterXY Az: 55az
# Index: 11 Value:  counterXY Az: 51az
# Index: 12 Value:  counterXY Az: 46az
# Index: 13 Value:  counterXY Az: 42az
# Index: 14 Value:  counterXY Az: 37az
# Index: 15 Value:  counterXY Az: 33az
# Index: 16 Value:  counterXY Az: 28az
# Index: 17 Value:  counterXY Az: 24az
# Index: 18 Value:  counterXY Az: 19az
# Index: 19 Value:  counterXY Az: 15az
# Index: 20 Value:  counterXY Az: 10az
# Index: 21 Value:  counterXY Az: 06az
# Index: 22 Value:  counterNXY Az: 01az
# Index: 23 Value:  counterNXY Az: 97az
# Index: 24 Value:  counterXY Az: 92az
