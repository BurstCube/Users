# %%
from BurstCube.simGenerator import configurator
conf = configurator('config.yaml')

from BurstCube.bcSim import simFiles
sfs = simFiles('config.yaml')

print(sfs.sims[0].simFile)
type(sfs.sims[0].simFile)# fileN = 'FIN_1000.000keV_15.00ze_0.00az.inc1.id1.sim'
# Out:
# Loading /home/laura/Research/local_test/c_15_0//FIN_25.000keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0//FIN_27.186keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0//FIN_29.564keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0//FIN_32.149keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0//FIN_34.961keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0//FIN_38.018keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0//FIN_41.343keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0//FIN_44.959keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0//FIN_48.890keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0//FIN_53.166keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0//FIN_57.816keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0//FIN_62.872keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0//FIN_68.370keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0//FIN_74.349keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0//FIN_80.851keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0//FIN_87.922keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0//FIN_95.611keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0//FIN_103.972keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0//FIN_113.065keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0//FIN_122.953keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0//FIN_133.705keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0//FIN_145.398keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0//FIN_158.114keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0//FIN_171.941keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0//FIN_186.978keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0//FIN_203.330keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0//FIN_221.112keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0//FIN_240.449keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0//FIN_261.477keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0//FIN_284.343keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0//FIN_309.210keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0//FIN_336.251keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0//FIN_365.658keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0//FIN_397.635keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0//FIN_432.410keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0//FIN_470.225keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0//FIN_511.348keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0//FIN_556.067keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0//FIN_604.696keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0//FIN_657.579keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0//FIN_715.086keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0//FIN_777.622keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0//FIN_845.627keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0//FIN_919.580keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0//FIN_1000.000keV_15.00ze_0.00az.inc1.id1.sim
# /home/laura/Research/local_test/c_15_0//FIN_25.000keV_15.00ze_0.00az.inc1.id1.sim
# str

# %%
simulation = 0; detectOne = 0; detectTwo = 0; detectThree = 0; detectFour = 0
percentOne = 0; percentTwo = 0; percentThree = 0; percentFour = 0
# detectOneTot = 0
# detectTwoTot = 0
# detectThreeTot = 0
# detectFourTot = 0
    
detectTot = 0

doubTriggerDict = {}
triggerSim = []
triggerSimNum = []
triggerSimCount = []
triggerSimEnergy = []

simType = ''
count = -1

import numpy as np
# triggerData = np.zeros(len(self.sims)), dtype={'names': ['keV', 'ze', 'az', 'counterXX', 'counterNXX', 'counterNXY', 'counterXY'], 'formats': ['float32', 'float32', 'float32','float32', 'float32', 'float32', 'float32']}

for file in sfs.sims:
    simulation = simulation + 1
    count += 1
#     print(file.simFile)
    import re
    counterXX = 0
    counterNXX = 0
    counterNXY = 0
    counterXY = 0
    d = 0
    prevLine = 'random'
    counter = 0

    with open(file.simFile) as sim:

#         print(file.simFile)
#         triggerDict = {'trig': [0], 'd' : 'sample'}

        for i, line in enumerate(sim):

            if line.startswith('ID'):
                ID = line.split()

                for i in range(len(ID)):
                    trigger = ID[1]

            if line.startswith('HTsim'):
                data = line.split(";")
                data = [w.strip(' ') for w in data]
#                 counter = counter + 1
        
                data[1] = float(data[1])
                data[2] = float(data[2])
#                 print(data[1])
#                 print("HELLO")
#                 print(data[2])
#                 print("GOODBYE")
#                 for i in range(len(data)):
#                 triggerDict.setdefault('triggers', [])
#                 triggerDict.setdefault('d', [])

                
                if (abs(5.52500 - data[1]) <= 0.05) and  (abs(5.52500 - data[2]) <= .05):
                    counterXX += 1
                    
                    d = 1
#                     triggerDict['trig'].append(counterXX)
#                     triggerDict['d'].append(d)
                    
                elif (abs(-5.52500 - data[1]) <= 0.05) and  (abs(5.52500 - data[2]) <= .05):
                    counterNXX += 1
                    d = 2
#                     triggerDict['trig'].append(counterNXX)
#                     triggerDict['d'].append(d)
                    
                elif (abs(-5.52500 - data[1]) <= 0.05) and  (abs(-5.52500 - data[2]) <= .05):
                    counterNXY += 1
                    d = 3
#                     triggerDict['trig'].append(counterNXY)
#                     triggerDict['d'].append(d)
                    
                elif (abs(5.52500 - data[1]) <= 0.05) and  (abs(-5.52500 - data[2]) <= .05):
                    counterXY += 1
                    d = 4
#                     triggerDict['trig'].append(counterXY)
#                     triggerDict['d'].append(d)
                    
#                 detectOne = counterXX + detectOne
#                 detectTwo = counterNXX + detectTwo
#                 detectThree = counterNXY + detectThree
#                 detectFour = counterXY + detectFour
#                 print(detectOne)
#                 print(detectTwo)
#                 print(detectThree)
#                 print(detectFour)
#                 print('*****')
                counter += 1   
                
            if prevLine.startswith('HTsim') and line.startswith('HTsim'):
                sfo = re.split('[_ . //]', file.simFile)
#                 doubTriggerDict['energy'] = sfo[4]
#                 doubTriggerDict['zenith'] = sfo[6]
#                 doubTriggerDict['azimuth'] = sfo[8]
#                 doubTriggerDict['trigNum'] = trigger
    
            prevLine = line
            if counterXX > (counterNXX and counterNXY and counterXY):
                triggerSimMax = counterXX
                triggerSimType = 'counterXX'
            elif counterNXX > (counterXX and counterNXY and counterXY):
                triggerSimMax = counterNXX
                triggerSimType = 'counterNXX'
            elif counterNXY > (counterXX and counterNXX and counterXY):
                triggerSimMax = counterNXY
                triggerSimType = 'counterNXY'

            elif counterXY > (counterXX and counterNXX and counterNXY):
                triggerSimMax = counterXY
                triggerSimType = 'counterXY'
            sfo = re.split('[/ . _]', file.simFile)
    triggerSimCount.append(triggerSimType)
    triggerSimNum.append(triggerSimMax)
    triggerSim.append(triggerSimMax)
    triggerSim.append(triggerSimType)
    triggerSimEnergy.append(sfo[11])
    

    
#             print('***', trigger)

#             vars = re.split('[_ .]', file.simFile)
#             print("----------------------------------------------------------------------------")
#             print('Simulation', simulation, '--', trigger, ': Energy ({} keV), Azimuth ({} degrees), Zenith ({} degrees)'.format(vars[3], vars[5], vars[7]))
#             print("----------------------------------------------------------------------------")

#             print('Detector 1 has', counterXX , 'hits.')
#             print('Detector 2 has', counterNXX , 'hits.')
#             print('Detector 3 has', counterNXY , 'hits.')
#             print('Detector 4 has', counterXY , 'hits.')
        
#     print('**', count)
    detectOne = counterXX + detectOne
    detectTwo = counterNXX + detectTwo
    detectThree = counterNXY + detectThree
    detectFour = counterXY + detectFour

detectTot = detectOne + detectTwo + detectThree + detectFour
# print(detectOne, detectTot)
percentOne = detectOne / detectTot * 100
percentTwo = detectTwo / detectTot * 100
percentThree = detectThree / detectTot * 100
percentFour = detectFour / detectTot * 100

print('**', percentOne, "**", percentTwo, '**', percentThree, "**", percentFour, "**")
# print(triggerDict)

import operator
print(sorted(enumerate(triggerSimNum), key=operator.itemgetter(1)))

c = 1
for i in range(len(triggerSimCount)):
    print('Index:', c, ';Value: ', triggerSimCount[i], ';Energy:', triggerSimEnergy[i])
    c = c + 1
# Out:
# ** 28.00317866760849 ** 22.054213941989318 ** 21.85775462451989 ** 28.0848527658823 **
