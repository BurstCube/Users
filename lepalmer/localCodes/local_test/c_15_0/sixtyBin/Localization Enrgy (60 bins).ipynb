# %%
from BurstCube.simGenerator import configurator
conf = configurator('config.yaml')

from BurstCube.bcSim import simFiles
sfs = simFiles('config.yaml')

print(sfs.sims[0].simFile)
type(sfs.sims[0].simFile)# fileN = 'FIN_1000.000keV_15.00ze_0.00az.inc1.id1.sim'
# Out:
# Loading /home/laura/Research/local_test/c_15_0/sixtyBin//FIN_25.000keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0/sixtyBin//FIN_26.613keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0/sixtyBin//FIN_28.330keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0/sixtyBin//FIN_30.158keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0/sixtyBin//FIN_32.104keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0/sixtyBin//FIN_34.175keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0/sixtyBin//FIN_36.380keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0/sixtyBin//FIN_38.727keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0/sixtyBin//FIN_41.226keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0/sixtyBin//FIN_43.886keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0/sixtyBin//FIN_46.717keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0/sixtyBin//FIN_49.731keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0/sixtyBin//FIN_52.940keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0/sixtyBin//FIN_56.355keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0/sixtyBin//FIN_59.992keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0/sixtyBin//FIN_63.862keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0/sixtyBin//FIN_67.982keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0/sixtyBin//FIN_72.369keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0/sixtyBin//FIN_77.038keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0/sixtyBin//FIN_82.008keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0/sixtyBin//FIN_87.299keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0/sixtyBin//FIN_92.932keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0/sixtyBin//FIN_98.928keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0/sixtyBin//FIN_105.311keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0/sixtyBin//FIN_112.105keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0/sixtyBin//FIN_119.338keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0/sixtyBin//FIN_127.038keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0/sixtyBin//FIN_135.234keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0/sixtyBin//FIN_143.959keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0/sixtyBin//FIN_153.247keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0/sixtyBin//FIN_163.135keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0/sixtyBin//FIN_173.660keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0/sixtyBin//FIN_184.865keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0/sixtyBin//FIN_196.792keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0/sixtyBin//FIN_209.489keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0/sixtyBin//FIN_223.005keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0/sixtyBin//FIN_237.393keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0/sixtyBin//FIN_252.710keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0/sixtyBin//FIN_269.014keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0/sixtyBin//FIN_286.371keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0/sixtyBin//FIN_304.847keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0/sixtyBin//FIN_324.516keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0/sixtyBin//FIN_345.453keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0/sixtyBin//FIN_367.742keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0/sixtyBin//FIN_391.468keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0/sixtyBin//FIN_416.726keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0/sixtyBin//FIN_443.612keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0/sixtyBin//FIN_472.234keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0/sixtyBin//FIN_502.702keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0/sixtyBin//FIN_535.136keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0/sixtyBin//FIN_569.663keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0/sixtyBin//FIN_606.417keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0/sixtyBin//FIN_645.543keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0/sixtyBin//FIN_687.193keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0/sixtyBin//FIN_731.530keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0/sixtyBin//FIN_778.728keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0/sixtyBin//FIN_828.971keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0/sixtyBin//FIN_882.456keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0/sixtyBin//FIN_939.391keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Research/local_test/c_15_0/sixtyBin//FIN_1000.000keV_15.00ze_0.00az.inc1.id1.sim
# /home/laura/Research/local_test/c_15_0/sixtyBin//FIN_25.000keV_15.00ze_0.00az.inc1.id1.sim
# str

# %%
simulation = 0; detectOne = 0; detectTwo = 0; detectThree = 0; detectFour = 0
percentOne = 0; percentTwo = 0; percentThree = 0; percentFour = 0
# detectOneTot = 0
# detectTwoTot = 0
# detectThreeTot = 0
# detectFourTot = 0
    
detectTot = 0

doubTriggerDict = {}
triggerSim = []
triggerSimNum = []
triggerSimCount = []
triggerSimEnergy = []

simType = ''
count = -1

import numpy as np
# triggerData = np.zeros(len(self.sims)), dtype={'names': ['keV', 'ze', 'az', 'counterXX', 'counterNXX', 'counterNXY', 'counterXY'], 'formats': ['float32', 'float32', 'float32','float32', 'float32', 'float32', 'float32']}

for file in sfs.sims:
    simulation = simulation + 1
    count += 1
#     print(file.simFile)
    import re
    counterXX = 0
    counterNXX = 0
    counterNXY = 0
    counterXY = 0
    d = 0
    prevLine = 'random'
    counter = 0

    with open(file.simFile) as sim:

#         print(file.simFile)
#         triggerDict = {'trig': [0], 'd' : 'sample'}

        for i, line in enumerate(sim):

            if line.startswith('ID'):
                ID = line.split()

                for i in range(len(ID)):
                    trigger = ID[1]

            if line.startswith('HTsim'):
                data = line.split(";")
                data = [w.strip(' ') for w in data]
#                 counter = counter + 1
        
                data[1] = float(data[1])
                data[2] = float(data[2])
#                 print(data[1])
#                 print("HELLO")
#                 print(data[2])
#                 print("GOODBYE")
#                 for i in range(len(data)):
#                 triggerDict.setdefault('triggers', [])
#                 triggerDict.setdefault('d', [])

                
                if (abs(5.52500 - data[1]) <= 0.05) and  (abs(5.52500 - data[2]) <= .05):
                    counterXX += 1
                    
                    d = 1
#                     triggerDict['trig'].append(counterXX)
#                     triggerDict['d'].append(d)
                    
                elif (abs(-5.52500 - data[1]) <= 0.05) and  (abs(5.52500 - data[2]) <= .05):
                    counterNXX += 1
                    d = 2
#                     triggerDict['trig'].append(counterNXX)
#                     triggerDict['d'].append(d)
                    
                elif (abs(-5.52500 - data[1]) <= 0.05) and  (abs(-5.52500 - data[2]) <= .05):
                    counterNXY += 1
                    d = 3
#                     triggerDict['trig'].append(counterNXY)
#                     triggerDict['d'].append(d)
                    
                elif (abs(5.52500 - data[1]) <= 0.05) and  (abs(-5.52500 - data[2]) <= .05):
                    counterXY += 1
                    d = 4
#                     triggerDict['trig'].append(counterXY)
#                     triggerDict['d'].append(d)
                    
#                 detectOne = counterXX + detectOne
#                 detectTwo = counterNXX + detectTwo
#                 detectThree = counterNXY + detectThree
#                 detectFour = counterXY + detectFour
#                 print(detectOne)
#                 print(detectTwo)
#                 print(detectThree)
#                 print(detectFour)
#                 print('*****')
                counter += 1   
                
            if prevLine.startswith('HTsim') and line.startswith('HTsim'):
                sfo = re.split('[_ . //]', file.simFile)
#                 doubTriggerDict['energy'] = sfo[4]
#                 doubTriggerDict['zenith'] = sfo[6]
#                 doubTriggerDict['azimuth'] = sfo[8]
#                 doubTriggerDict['trigNum'] = trigger
    
            prevLine = line
            if counterXX > (counterNXX and counterNXY and counterXY):
                triggerSimMax = counterXX
                triggerSimType = 'counterXX'
            elif counterNXX > (counterXX and counterNXY and counterXY):
                triggerSimMax = counterNXX
                triggerSimType = 'counterNXX'
            elif counterNXY > (counterXX and counterNXX and counterXY):
                triggerSimMax = counterNXY
                triggerSimType = 'counterNXY'

            elif counterXY > (counterXX and counterNXX and counterNXY):
                triggerSimMax = counterXY
                triggerSimType = 'counterXY'
            sfo = re.split('[/ _]', file.simFile)
    triggerSimCount.append(triggerSimType)
    triggerSimNum.append(triggerSimMax)
    triggerSim.append(triggerSimMax)
    triggerSim.append(triggerSimType)
    triggerSimEnergy.append(sfo[12])
    

    
#             print('***', trigger)

#             vars = re.split('[_ .]', file.simFile)
#             print("----------------------------------------------------------------------------")
#             print('Simulation', simulation, '--', trigger, ': Energy ({} keV), Azimuth ({} degrees), Zenith ({} degrees)'.format(vars[3], vars[5], vars[7]))
#             print("----------------------------------------------------------------------------")

#             print('Detector 1 has', counterXX , 'hits.')
#             print('Detector 2 has', counterNXX , 'hits.')
#             print('Detector 3 has', counterNXY , 'hits.')
#             print('Detector 4 has', counterXY , 'hits.')
        
#     print('**', count)
    detectOne = counterXX + detectOne
    detectTwo = counterNXX + detectTwo
    detectThree = counterNXY + detectThree
    detectFour = counterXY + detectFour

detectTot = detectOne + detectTwo + detectThree + detectFour
# print(detectOne, detectTot)
percentOne = detectOne / detectTot * 100
percentTwo = detectTwo / detectTot * 100
percentThree = detectThree / detectTot * 100
percentFour = detectFour / detectTot * 100

print('**', percentOne, "**", percentTwo, '**', percentThree, "**", percentFour, "**")
# print(triggerDict)

import operator
print(sorted(enumerate(triggerSimNum), key=operator.itemgetter(1)))

c = 1
for i in range(len(triggerSimCount)):
    print('Index:', c, ';Value: ', triggerSimCount[i], ';Energy:', triggerSimEnergy[i])
    c = c + 1
# Out:
# ** 27.685102439347304 ** 22.20236322112998 ** 22.250355807102903 ** 27.86217853241982 **
# [(58, 267), (48, 269), (51, 269), (26, 270), (29, 272), (41, 273), (25, 274), (34, 274), (53, 274), (54, 274), (57, 274), (55, 275), (45, 276), (56, 276), (24, 278), (43, 278), (46, 278), (50, 278), (18, 280), (27, 280), (11, 282), (30, 283), (33, 284), (59, 284), (9, 285), (10, 285), (36, 285), (19, 286), (20, 287), (28, 287), (31, 287), (35, 287), (14, 288), (17, 288), (47, 289), (23, 290), (21, 291), (37, 291), (39, 291), (16, 293), (15, 294), (49, 294), (42, 295), (52, 295), (8, 296), (40, 296), (32, 297), (5, 298), (12, 301), (44, 302), (3, 304), (38, 304), (6, 306), (22, 306), (1, 307), (13, 308), (2, 310), (7, 310), (4, 311), (0, 317)]
# Index: 1 ;Value:  counterXX ;Energy: 25.000keV
# Index: 2 ;Value:  counterXX ;Energy: 26.613keV
