# %%
from BurstCube.bcSim import simFiles

# %%
sfs = simFiles('../test4/config.yaml')
# Out:
# Loading /home/laura/Simulation/BurstCube/data/test4//test_25.000keV_0.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Simulation/BurstCube/data/test4//test_52.282keV_0.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Simulation/BurstCube/data/test4//test_109.336keV_0.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Simulation/BurstCube/data/test4//test_228.653keV_0.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Simulation/BurstCube/data/test4//test_478.176keV_0.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Simulation/BurstCube/data/test4//test_1000.000keV_0.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Simulation/BurstCube/data/test4//test_25.000keV_0.00ze_30.00az.inc1.id1.sim
# Loading /home/laura/Simulation/BurstCube/data/test4//test_52.282keV_0.00ze_30.00az.inc1.id1.sim
# Loading /home/laura/Simulation/BurstCube/data/test4//test_109.336keV_0.00ze_30.00az.inc1.id1.sim
# Loading /home/laura/Simulation/BurstCube/data/test4//test_228.653keV_0.00ze_30.00az.inc1.id1.sim
# Loading /home/laura/Simulation/BurstCube/data/test4//test_478.176keV_0.00ze_30.00az.inc1.id1.sim
# Loading /home/laura/Simulation/BurstCube/data/test4//test_1000.000keV_0.00ze_30.00az.inc1.id1.sim
# Loading /home/laura/Simulation/BurstCube/data/test4//test_25.000keV_0.00ze_60.00az.inc1.id1.sim
# Loading /home/laura/Simulation/BurstCube/data/test4//test_52.282keV_0.00ze_60.00az.inc1.id1.sim
# Loading /home/laura/Simulation/BurstCube/data/test4//test_109.336keV_0.00ze_60.00az.inc1.id1.sim
# Loading /home/laura/Simulation/BurstCube/data/test4//test_228.653keV_0.00ze_60.00az.inc1.id1.sim
# Loading /home/laura/Simulation/BurstCube/data/test4//test_478.176keV_0.00ze_60.00az.inc1.id1.sim
# Loading /home/laura/Simulation/BurstCube/data/test4//test_1000.000keV_0.00ze_60.00az.inc1.id1.sim

# %%
import numpy as np
energies = np.empty([len(sfs.sims)])
for i, S in enumerate(sfs.sims):
    energies[i] = S.energy

# %%
area = sfs.calculateAeff(useEres=False, sigma=2.0)

# %%
print(area)
# Out:
# [( 0., 0.,   25.      , 32.708298, 32.577465, 32.577465)
#  ( 0., 0.,   52.28198 , 74.520195, 63.416687, 72.80623 )
#  ( 0., 0.,  109.336205, 76.43406 , 70.62507 , 74.29391 )
#  ( 0., 0.,  228.65253 , 75.31267 , 67.25421 , 69.664215)
#  ( 0., 0.,  478.17624 , 47.367645, 28.988998, 29.652145)
#  ( 0., 0., 1000.      , 36.07924 , 12.735971, 25.508022)
#  (30., 0.,   25.      , 32.71974 , 32.687023, 32.687023)
#  (30., 0.,   52.28198 , 69.22797 , 58.013035, 67.77418 )
#  (30., 0.,  109.336205, 76.83936 , 70.76905 , 74.68786 )
#  (30., 0.,  228.65253 , 71.986855, 64.86015 , 66.875786)
#  (30., 0.,  478.17624 , 49.99097 , 30.79444 , 31.194366)
#  (30., 0., 1000.      , 34.351166, 13.122145, 26.27864 )
#  (60., 0.,   25.      , 32.725334, 32.692608, 32.692608)
#  (60., 0.,   52.28198 , 69.10066 , 60.25578 , 67.71865 )
#  (60., 0.,  109.336205, 78.78326 , 73.583565, 76.971245)
#  (60., 0.,  228.65253 , 68.945984, 61.499817, 63.36136 )
#  (60., 0.,  478.17624 , 49.864967, 31.714119, 32.3125  )
#  (60., 0., 1000.      , 36.216995, 13.327855, 26.65571 )]

# %%
sfs.sims
# Out:
# [<BurstCube.bcSim.simFile at 0x7f7d601222e8>,
#  <BurstCube.bcSim.simFile at 0x7f7d60089ac8>,
#  <BurstCube.bcSim.simFile at 0x7f7d60122320>,
#  <BurstCube.bcSim.simFile at 0x7f7d430d1908>,
#  <BurstCube.bcSim.simFile at 0x7f7d429da550>,
#  <BurstCube.bcSim.simFile at 0x7f7d430d1390>,
#  <BurstCube.bcSim.simFile at 0x7f7d41943c50>,
#  <BurstCube.bcSim.simFile at 0x7f7d40ff55f8>,
#  <BurstCube.bcSim.simFile at 0x7f7d40c0be48>,
#  <BurstCube.bcSim.simFile at 0x7f7d40549940>,
#  <BurstCube.bcSim.simFile at 0x7f7d3fe51940>,
#  <BurstCube.bcSim.simFile at 0x7f7d3f68b4a8>,
#  <BurstCube.bcSim.simFile at 0x7f7d3e4eae48>,
#  <BurstCube.bcSim.simFile at 0x7f7d3e4eaeb8>,
#  <BurstCube.bcSim.simFile at 0x7f7d3e084780>,
#  <BurstCube.bcSim.simFile at 0x7f7d3da9e940>,
#  <BurstCube.bcSim.simFile at 0x7f7d3d2b8710>,
#  <BurstCube.bcSim.simFile at 0x7f7d3cb6f278>]

# %%
sfs.calculateAeff()
# Out:
# array([( 0., 0.,   25.      , 32.708298, 32.577465, 32.577465),
#        ( 0., 0.,   52.28198 , 74.520195, 63.416687, 72.80623 ),
#        ( 0., 0.,  109.336205, 76.43406 , 70.62507 , 74.29391 ),
#        ( 0., 0.,  228.65253 , 75.31267 , 67.25421 , 69.664215),
#        ( 0., 0.,  478.17624 , 47.367645, 28.988998, 29.652145),
#        ( 0., 0., 1000.      , 36.07924 , 12.735971, 25.508022),
#        (30., 0.,   25.      , 32.71974 , 32.687023, 32.687023),
#        (30., 0.,   52.28198 , 69.22797 , 58.013035, 67.77418 ),
#        (30., 0.,  109.336205, 76.83936 , 70.76905 , 74.68786 ),
#        (30., 0.,  228.65253 , 71.986855, 64.86015 , 66.875786),
#        (30., 0.,  478.17624 , 49.99097 , 30.79444 , 31.194366),
#        (30., 0., 1000.      , 34.351166, 13.122145, 26.27864 ),
#        (60., 0.,   25.      , 32.725334, 32.692608, 32.692608),
#        (60., 0.,   52.28198 , 69.10066 , 60.25578 , 67.71865 ),
#        (60., 0.,  109.336205, 78.78326 , 73.583565, 76.971245),
#        (60., 0.,  228.65253 , 68.945984, 61.499817, 63.36136 ),
#        (60., 0.,  478.17624 , 49.864967, 31.714119, 32.3125  ),
#        (60., 0., 1000.      , 36.216995, 13.327855, 26.65571 )],
#       dtype=[('az', '<f4'), ('ze', '<f4'), ('keV', '<f4'), ('aeff', '<f4'), ('aeff_eres', '<f4'), ('aeff_eres_modfrac', '<f4')])

# %%
aeff = sfs.calculateAeff()
gEres = list(aeff['aeff_eres'])
bEres = list(aeff['aeff_eres_modfrac'])
Area = list(aeff['aeff'])
azimuth = list(aeff['az'])

# %%
from BurstCube.plotSim import plotAeffvsEnergy
plotAeffvsEnergy(energies[0:6], Area[0:6], gEres[0:6], bEres[0:6], az=0, ze=0)
import matplotlib.pyplot as plt
plt.show()

# %%
plotAeffvsEnergy(energies[0:6], Area[0:6], gEres[0:6], bEres[0:6], ze= 15, plotGBM=True)

# %%
zens = np.empty([len(sfs.sims)])
for i, S in enumerate(sfs.sims):
    zens[i] = S.zenith

# %%
from BurstCube.plotSim import plotAeffvsTheta
plotAeffvsTheta(zens, Area, gEres, bEres)

# %%
def plotAeffvsPhi(azimuth, aeff, aeff_eres, aeff_eres_modfrac):

    """Plots the GBM NaI effective area against the polar angle phi used
    to generate that source.
    
    Parameters
    ----------
    azimuth : array
       numpy array of the angle in deg of the source. 
    aeff : array
        numpy array with GBM NaI effective area. 
    aeff_eres : array
        I'll look up energy resulution later
    aeff_eres_modfrac : array
        plus escape? 
    Returns
    ----------
    a plot!
    """
    plt.figure(figsize=(8, 6))
    plt.title('Effective Area vs. Angle')
    plt.scatter(azimuth, aeff, color='black')
    plt.plot(azimuth, aeff, color='black', alpha=0.5, linestyle='--',
             lw=2, label='BurstCube')
    plt.scatter(azimuth, aeff_eres, color='blue')
    plt.plot(azimuth, aeff_eres, color='blue', alpha=0.5, linestyle='--',
             lw=2, label='BurstCube with E$_{\mathrm{res}}$')
    plt.scatter(azimuth, aeff_eres_modfrac, color='red')
    plt.plot(azimuth, aeff_eres_modfrac, color='red', alpha=0.5, linestyle='--',
             lw=2, label='BurstCube with E$_{\mathrm{res}}$ + escape')

    plt.xlabel('Azimuth Angle (deg)', fontsize=16)
    plt.ylabel('Effective Area (cm$^2$)', fontsize=16)
    plt.legend(loc='lower center', scatterpoints=1, prop={'size': 16},
               frameon=False)
    plt.axis('tight')
plt.grid(True)

# %%
plotAeffvsPhi(azimuth, Area, gEres, bEres)

# %%
print(zens[0:3])
# Out:
# [0. 0. 0.]
