# %%
from BurstCube.bcSim import simFiles

# %% [markdown]
# * Made a new directory, test3, to simulate a config file with energies of 25 to 1000 keV with incidence of 15 degrees
# * Bins = 6

# %%
sfs = simFiles('../test3/config.yaml')
# Out:
# Loading /home/laura/Simulation/BurstCube/data/test3//test_25.000keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Simulation/BurstCube/data/test3//test_52.282keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Simulation/BurstCube/data/test3//test_109.336keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Simulation/BurstCube/data/test3//test_228.653keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Simulation/BurstCube/data/test3//test_478.176keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Simulation/BurstCube/data/test3//test_1000.000keV_15.00ze_0.00az.inc1.id1.sim
# Loading /home/laura/Simulation/BurstCube/data/test3//test_25.000keV_15.00ze_30.00az.inc1.id1.sim
# Loading /home/laura/Simulation/BurstCube/data/test3//test_52.282keV_15.00ze_30.00az.inc1.id1.sim
# Loading /home/laura/Simulation/BurstCube/data/test3//test_109.336keV_15.00ze_30.00az.inc1.id1.sim
# Loading /home/laura/Simulation/BurstCube/data/test3//test_228.653keV_15.00ze_30.00az.inc1.id1.sim
# Loading /home/laura/Simulation/BurstCube/data/test3//test_478.176keV_15.00ze_30.00az.inc1.id1.sim
# Loading /home/laura/Simulation/BurstCube/data/test3//test_1000.000keV_15.00ze_30.00az.inc1.id1.sim
# Loading /home/laura/Simulation/BurstCube/data/test3//test_25.000keV_15.00ze_60.00az.inc1.id1.sim
# Loading /home/laura/Simulation/BurstCube/data/test3//test_52.282keV_15.00ze_60.00az.inc1.id1.sim
# Loading /home/laura/Simulation/BurstCube/data/test3//test_109.336keV_15.00ze_60.00az.inc1.id1.sim
# Loading /home/laura/Simulation/BurstCube/data/test3//test_228.653keV_15.00ze_60.00az.inc1.id1.sim
# Loading /home/laura/Simulation/BurstCube/data/test3//test_478.176keV_15.00ze_60.00az.inc1.id1.sim
# Loading /home/laura/Simulation/BurstCube/data/test3//test_1000.000keV_15.00ze_60.00az.inc1.id1.sim

# %%
import numpy as np
energies = np.empty([len(sfs.sims)])
for i, S in enumerate(sfs.sims):
    energies[i] = S.energy

# %%
area = sfs.calculateAeff(useEres=False, sigma=2.0)

# %%
print(area)
# Out:
# [( 0., 15.,   25.      , 30.327415, 30.175777, 30.175777)
#  ( 0., 15.,   52.28198 , 71.77371 , 58.99799 , 70.12292 )
#  ( 0., 15.,  109.336205, 78.04811 , 72.116455, 75.86276 )
#  ( 0., 15.,  228.65253 , 69.26215 , 61.57405 , 63.651917)
#  ( 0., 15.,  478.17624 , 47.014908, 27.926857, 28.302975)
#  ( 0., 15., 1000.      , 37.499016, 14.13713 , 28.311758)
#  (30., 15.,   25.      , 29.877703, 29.817947, 29.817947)
#  (30., 15.,   52.28198 , 74.04945 , 63.016087, 72.42037 )
#  (30., 15.,  109.336205, 79.490524, 73.52873 , 77.185295)
#  (30., 15.,  228.65253 , 70.90735 , 62.82391 , 64.6675  )
#  (30., 15.,  478.17624 , 49.525063, 29.764563, 30.210289)
#  (30., 15., 1000.      , 36.13867 , 13.515863, 27.104004)
#  (60., 15.,   25.      , 31.09281 , 30.937346, 30.937346)
#  (60., 15.,   52.28198 , 71.205635, 59.243088, 69.71032 )
#  (60., 15.,  109.336205, 81.35553 , 74.84709 , 78.91486 )
#  (60., 15.,  228.65253 , 71.68331 , 63.869827, 65.94865 )
#  (60., 15.,  478.17624 , 47.791054, 29.248125, 29.726034)
#  (60., 15., 1000.      , 37.43735 , 13.065635, 26.168707)]

# %%
sfs.sims
# Out:
# [<BurstCube.bcSim.simFile at 0x7f1f85f11828>,
#  <BurstCube.bcSim.simFile at 0x7f1f861025c0>,
#  <BurstCube.bcSim.simFile at 0x7f1f85f117f0>,
#  <BurstCube.bcSim.simFile at 0x7f1f85287eb8>,
#  <BurstCube.bcSim.simFile at 0x7f1f85287f28>,
#  <BurstCube.bcSim.simFile at 0x7f1f84ac8668>,
#  <BurstCube.bcSim.simFile at 0x7f1f84245828>,
#  <BurstCube.bcSim.simFile at 0x7f1f838d7668>,
#  <BurstCube.bcSim.simFile at 0x7f1f83468be0>,
#  <BurstCube.bcSim.simFile at 0x7f1f82e12828>,
#  <BurstCube.bcSim.simFile at 0x7f1f82702208>,
#  <BurstCube.bcSim.simFile at 0x7f1f81f40b70>,
#  <BurstCube.bcSim.simFile at 0x7f1f816d40f0>,
#  <BurstCube.bcSim.simFile at 0x7f1f80d49fd0>,
#  <BurstCube.bcSim.simFile at 0x7f1f80d4d048>,
#  <BurstCube.bcSim.simFile at 0x7f1f80298908>,
#  <BurstCube.bcSim.simFile at 0x7f1f7fb27f98>,
#  <BurstCube.bcSim.simFile at 0x7f1f7f3cf780>]

# %%
sfs.calculateAeff()
# Out:
# array([( 0., 15.,   25.      , 30.327415, 30.175777, 30.175777),
#        ( 0., 15.,   52.28198 , 71.77371 , 58.99799 , 70.12292 ),
#        ( 0., 15.,  109.336205, 78.04811 , 72.116455, 75.86276 ),
#        ( 0., 15.,  228.65253 , 69.26215 , 61.57405 , 63.651917),
#        ( 0., 15.,  478.17624 , 47.014908, 27.926857, 28.302975),
#        ( 0., 15., 1000.      , 37.499016, 14.13713 , 28.311758),
#        (30., 15.,   25.      , 29.877703, 29.817947, 29.817947),
#        (30., 15.,   52.28198 , 74.04945 , 63.016087, 72.42037 ),
#        (30., 15.,  109.336205, 79.490524, 73.52873 , 77.185295),
#        (30., 15.,  228.65253 , 70.90735 , 62.82391 , 64.6675  ),
#        (30., 15.,  478.17624 , 49.525063, 29.764563, 30.210289),
#        (30., 15., 1000.      , 36.13867 , 13.515863, 27.104004),
#        (60., 15.,   25.      , 31.09281 , 30.937346, 30.937346),
#        (60., 15.,   52.28198 , 71.205635, 59.243088, 69.71032 ),
#        (60., 15.,  109.336205, 81.35553 , 74.84709 , 78.91486 ),
#        (60., 15.,  228.65253 , 71.68331 , 63.869827, 65.94865 ),
#        (60., 15.,  478.17624 , 47.791054, 29.248125, 29.726034),
#        (60., 15., 1000.      , 37.43735 , 13.065635, 26.168707)],
#       dtype=[('az', '<f4'), ('ze', '<f4'), ('keV', '<f4'), ('aeff', '<f4'), ('aeff_eres', '<f4'), ('aeff_eres_modfrac', '<f4')])

# %%
#Extracted the elements from the area array
aeff = sfs.calculateAeff()

gEres = list(aeff['aeff_eres'])
bEres = list(aeff['aeff_eres_modfrac'])
Area = list(aeff['aeff'])
azimuth = list(aeff['az'])

# %%
#plotting area against energy, azimuth is not constant (disregard title)
from BurstCube.plotSim import plotAeffvsEnergy
plotAeffvsEnergy(energies[0:6], Area[0:6], gEres[0:6], bEres[0:6], az=0, ze=15)
import matplotlib.pyplot as plt
plt.show()

# %%
#plotting area against energy with GBM data, azimuth is not constant (disregard title)
plotAeffvsEnergy(energies[0:6], Area[0:6], gEres[0:6], bEres[0:6], ze= 15, plotGBM=True)

# %%
zens = np.empty([len(sfs.sims)])
for i, S in enumerate(sfs.sims):
    zens[i] = S.zenith

# %%
#plotted the effective area against the incidence, energy is not constant (disregard title)
from BurstCube.plotSim import plotAeffvsTheta
plotAeffvsTheta(zens[0:3], Area[0:3], gEres[0:3], bEres[0:3])

# %%
#plotted the effective area against the incidence, energy is not constant (disregard title)
from BurstCube.plotSim import plotAeffvsTheta
plotAeffvsTheta(zens, Area, gEres, bEres)

# %%
#created a function to plot the effective area against the azimuth angle
def plotAeffvsPhi(azimuth, aeff, aeff_eres, aeff_eres_modfrac,
                    energy=100., paren=''):

    """Plots the GBM NaI effective area against the polar angle phi used
    to generate that source.
    
    Parameters
    ----------
    azimuth : array
       numpy array of the angle in deg of the source. 
    aeff : array
        numpy array with GBM NaI effective area. 
    aeff_eres : array
        I'll look up energy resulution later
    aeff_eres_modfrac : array
        plus escape? 
    Returns
    ----------
    a plot!
    """
    plt.figure(figsize=(8, 6))
    plt.title(r'Effective Area vs. Angle (E = {:,.0f} keV{})'
              .format(energy, paren))
    plt.scatter(azimuth, aeff, color='black')
    plt.plot(azimuth, aeff, color='black', alpha=0.5, linestyle='--',
             lw=2, label='BurstCube')
    plt.scatter(azimuth, aeff_eres, color='blue')
    plt.plot(azimuth, aeff_eres, color='blue', alpha=0.5, linestyle='--',
             lw=2, label='BurstCube with E$_{\mathrm{res}}$')
    plt.scatter(azimuth, aeff_eres_modfrac, color='red')
    plt.plot(azimuth, aeff_eres_modfrac, color='red', alpha=0.5, linestyle='--',
             lw=2, label='BurstCube with E$_{\mathrm{res}}$ + escape')

    plt.xlabel('Azimuth Angle (deg)', fontsize=16)
    plt.ylabel('Effective Area (cm$^2$)', fontsize=16)
    plt.legend(loc='lower center', scatterpoints=1, prop={'size': 16},
               frameon=False)
    plt.axis('tight')
plt.grid(True)

# %%
#plotted the effective area against the azimuth, energy is not constant (disregard title)
plotAeffvsPhi(azimuth[0:3], Area[0:3], gEres[0:3], bEres[0:3])

# %%
#plotted the effective area against the azimuth, energy is not constant (disregard title)
#from BurstCube.plotSim import plotAeffvsPhi
plotAeffvsPhi(azimuth, Area, gEres, bEres)
